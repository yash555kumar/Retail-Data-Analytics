# %% [markdown]
# # Retail Data Analytics

# %% [markdown]
# ## Initial Exploratory Data Analysis

# %% [markdown]
# Goal of this project is to predict the sales of a Retail outlet based on the historical data provided for sales. A retailer wants to know the sales of his outlet in different locations across the country. This gives him a best understanding of scaling his business and to use the best practices which improves the sales of outlets. We have been given two kinds of data, one of them have historical data of sales across different outlets. For the other one we need to predict the sales based on the different parameters given. As we move through the various steps, we build a model to predict the sales of Retail Store.

# %% [markdown]
# In the first step we are going to acquire data into dataframes for further processing.

# %%
import numpy as np
import pandas as pd
data_Train = pd.read_csv("Train_Retail.csv",index_col="Item_Identifier")
data_Test = pd.read_csv("Test_Retail.csv",index_col="Item_Identifier")

# %%
data_Train.shape
# Out:
# (8523, 11)

# %%
data_Test.shape
# Out:
# (5681, 10)

# %% [markdown]
# In last few steps we loaded the data from Test and Train datasets into the data frames data_Test and data_Train respectively. Shape function gives us the shape i.e. number of rows and columns present in the dataframe. Train dataset has 8523 rows and 11 columns and data_Test has 5681 rows and 10 columns in it.

# %% [markdown]
# While predicting an outcome it is always important to understand our dataset properly and know the effecting features in the dataset. Let's have a look into the dataset given for training and test data.

# %%
data_Train.head
# Out:
# <bound method NDFrame.head of                  Item_Weight Item_Fat_Content  Item_Visibility  \
# Item_Identifier
# FDA15                  9.300          Low Fat         0.016047
# DRC01                  5.920          Regular         0.019278
# FDN15                 17.500          Low Fat         0.016760
# FDX07                 19.200          Regular         0.000000
# NCD19                  8.930          Low Fat         0.000000
# FDP36                 10.395          Regular         0.000000
# FDO10                 13.650          Regular         0.012741
# FDP10                    NaN          Low Fat         0.127470
# FDH17                 16.200          Regular         0.016687
# FDU28                 19.200          Regular         0.094450
# FDY07                 11.800          Low Fat         0.000000
# FDA03                 18.500          Regular         0.045464
# FDX32                 15.100          Regular         0.100014
# FDS46                 17.600          Regular         0.047257
# FDF32                 16.350          Low Fat         0.068024
# FDP49                  9.000          Regular         0.069089
# NCB42                 11.800          Low Fat         0.008596
# FDP49                  9.000          Regular         0.069196
# DRI11                    NaN          Low Fat         0.034238
# FDU02                 13.350          Low Fat         0.102492
# FDN22                 18.850          Regular         0.138190
# FDW12                    NaN          Regular         0.035400
# NCB30                 14.600          Low Fat         0.025698
# FDC37                    NaN          Low Fat         0.057557
# FDR28                 13.850          Regular         0.025896
# NCD06                 13.000          Low Fat         0.099887
# FDV10                  7.645          Regular         0.066693
# DRJ59                 11.650          low fat         0.019356
# FDE51                  5.925          Regular         0.161467
# FDC14                    NaN          Regular         0.072222
# ...                      ...              ...              ...
# FDP21                  7.420          Regular         0.025886
# NCI54                 15.200          Low Fat         0.000000
# FDE22                  9.695          Low Fat         0.029567
# FDJ57                  7.420          Regular         0.021696
# FDT08                 13.650          Low Fat         0.049209
# NCP54                 15.350          Low Fat         0.035293
# NCK53                 11.600          Low Fat         0.037574
# NCQ42                 20.350          Low Fat         0.000000
# FDW21                  5.340          Regular         0.005998
# NCH43                  8.420          Low Fat         0.070712
# FDQ44                 20.500          Low Fat         0.036133
# NCN18                    NaN          Low Fat         0.124111
# FDB46                 10.500          Regular         0.094146
# DRF37                 17.250          Low Fat         0.084676
# FDN28                  5.880          Regular         0.030242
# FDW31                 11.350          Regular         0.043246
# FDG45                  8.100          Low Fat         0.214306
# FDN58                 13.800          Regular         0.056862
# FDF05                 17.500          Low Fat         0.026980
# FDR26                 20.700          Low Fat         0.042801
# FDH31                 12.000          Regular         0.020407
# FDA01                 15.000          Regular         0.054489
# FDH24                 20.700          Low Fat         0.021518
# NCJ19                 18.600          Low Fat         0.118661
# FDF53                 20.750              reg         0.083607
# FDF22                  6.865          Low Fat         0.056783
# FDS36                  8.380          Regular         0.046982
# NCJ29                 10.600          Low Fat         0.035186
# FDN46                  7.210          Regular         0.145221
# DRG01                 14.800          Low Fat         0.044878
#
#                              Item_Type  Item_MRP Outlet_Identifier  \
# Item_Identifier
# FDA15                            Dairy  249.8092            OUT049
# DRC01                      Soft Drinks   48.2692            OUT018
# FDN15                             Meat  141.6180            OUT049
# FDX07            Fruits and Vegetables  182.0950            OUT010
# NCD19                        Household   53.8614            OUT013
# FDP36                     Baking Goods   51.4008            OUT018
# FDO10                      Snack Foods   57.6588            OUT013
# FDP10                      Snack Foods  107.7622            OUT027
# FDH17                     Frozen Foods   96.9726            OUT045
# FDU28                     Frozen Foods  187.8214            OUT017
# FDY07            Fruits and Vegetables   45.5402            OUT049
# FDA03                            Dairy  144.1102            OUT046
# FDX32            Fruits and Vegetables  145.4786            OUT049
# FDS46                      Snack Foods  119.6782            OUT046
# FDF32            Fruits and Vegetables  196.4426            OUT013
# FDP49                        Breakfast   56.3614            OUT046
# NCB42               Health and Hygiene  115.3492            OUT018
# FDP49                        Breakfast   54.3614            OUT049
# DRI11                      Hard Drinks  113.2834            OUT027
# FDU02                            Dairy  230.5352            OUT035
# FDN22                      Snack Foods  250.8724            OUT013
# FDW12                     Baking Goods  144.5444            OUT027
# NCB30                        Household  196.5084            OUT035
# FDC37                     Baking Goods  107.6938            OUT019
# FDR28                     Frozen Foods  165.0210            OUT046
# NCD06                        Household   45.9060            OUT017
# FDV10                      Snack Foods   42.3112            OUT035
# DRJ59                      Hard Drinks   39.1164            OUT013
# FDE51                            Dairy   45.5086            OUT010
# FDC14                           Canned   43.6454            OUT019
# ...                                ...       ...               ...
# FDP21                      Snack Foods  189.1872            OUT017
# NCI54                        Household  110.4912            OUT017
# FDE22                      Snack Foods  160.4920            OUT035
# FDJ57                          Seafood  185.3582            OUT017
# FDT08            Fruits and Vegetables  150.0050            OUT035
# NCP54                        Household  124.5730            OUT018
# NCK53               Health and Hygiene  100.0042            OUT035
# NCQ42                        Household  125.1678            OUT017
# FDW21                      Snack Foods  100.4358            OUT017
# NCH43                        Household  216.4192            OUT045
# FDQ44            Fruits and Vegetables  120.1756            OUT035
# NCN18                        Household  111.7544            OUT027
# FDB46                      Snack Foods  210.8244            OUT018
# DRF37                      Soft Drinks  263.1910            OUT018
# FDN28                     Frozen Foods  101.7990            OUT035
# FDW31            Fruits and Vegetables  199.4742            OUT045
# FDG45            Fruits and Vegetables  213.9902            OUT010
# FDN58                      Snack Foods  231.5984            OUT035
# FDF05                     Frozen Foods  262.5910            OUT018
# FDR26                            Dairy  178.3028            OUT013
# FDH31                             Meat   99.9042            OUT035
# FDX07                Grocery Store           732.3800
# NCD19            Supermarket Type1           994.7052
# FDP36            Supermarket Type2           556.6088
# FDO10            Supermarket Type1           343.5528
# FDP10            Supermarket Type3          4022.7636
# FDH17            Supermarket Type1          1076.5986
# FDU28            Supermarket Type1          4710.5350
# FDY07            Supermarket Type1          1516.0266
# FDA03            Supermarket Type1          2187.1530
# FDX32            Supermarket Type1          1589.2646
# FDS46            Supermarket Type1          2145.2076
# FDF32            Supermarket Type1          1977.4260
# FDP49            Supermarket Type1          1547.3192
# NCB42            Supermarket Type2          1621.8888
# FDP49            Supermarket Type1           718.3982
# DRI11            Supermarket Type3          2303.6680
# FDU02            Supermarket Type1          2748.4224
# FDN22            Supermarket Type1          3775.0860
# FDW12            Supermarket Type3          4064.0432
# NCB30            Supermarket Type1          1587.2672
# FDC37                Grocery Store           214.3876
# FDR28            Supermarket Type1          4078.0250
# NCD06            Supermarket Type1           838.9080
# FDV10            Supermarket Type1          1065.2800
# DRJ59            Supermarket Type1           308.9312
# FDE51                Grocery Store           178.4344
# FDC14                Grocery Store           125.8362
# ...                            ...                ...
# FDP21            Supermarket Type1          4727.1800
# NCI54            Supermarket Type1          1637.8680
# FDE22            Supermarket Type1          4314.3840
# FDJ57            Supermarket Type1          3715.1640
# FDT08            Supermarket Type1          2247.0750
# NCP54            Supermarket Type2          1601.2490
# NCK53            Supermarket Type1          2976.1260
# NCQ42            Supermarket Type1          1907.5170
# FDW21            Supermarket Type1          1508.0370
# NCH43            Supermarket Type1          3020.0688
# FDQ44            Supermarket Type1          3392.9168
# NCN18            Supermarket Type3          4138.6128
# FDB46            Supermarket Type2          2117.2440
# DRF37            Supermarket Type2          3944.8650
# FDN28            Supermarket Type1           515.9950
# FDW31            Supermarket Type1          2587.9646
# FDG45                Grocery Store           424.7804
# FDN58            Supermarket Type1          7182.6504
# FDF05            Supermarket Type2          4207.8560
# FDR26            Supermarket Type1          2479.4392
# FDH31            Supermarket Type1           595.2252
# FDA01            Supermarket Type1           468.7232
# FDH24            Supermarket Type2          1571.2880
# NCJ19            Supermarket Type2           858.8820
# FDF53            Supermarket Type1          3608.6360
# FDF22            Supermarket Type1          2778.3834
# FDS36            Supermarket Type1           549.2850
# NCJ29            Supermarket Type1          1193.1136
# FDN46            Supermarket Type2          1845.5976
# DRG01            Supermarket Type1           765.6700
#
# [8523 rows x 11 columns]>

# %%
data_Test.head
# Out:
# <bound method NDFrame.head of                  Item_Weight Item_Fat_Content  Item_Visibility  \
# Item_Identifier
# FDW58                 20.750          Low Fat         0.007565
# FDW14                  8.300              reg         0.038428
# NCN55                 14.600          Low Fat         0.099575
# FDQ58                  7.315          Low Fat         0.015388
# FDY38                    NaN          Regular         0.118599
# FDH56                  9.800          Regular         0.063817
# FDL48                 19.350          Regular         0.082602
# FDC48                    NaN          Low Fat         0.015782
# FDN33                  6.305          Regular         0.123365
# FDA36                  5.985          Low Fat         0.005698
# FDT44                 16.600          Low Fat         0.103569
# FDQ56                  6.590          Low Fat         0.105811
# NCC54                    NaN          Low Fat         0.171079
# FDU11                  4.785          Low Fat         0.092738
# DRL59                 16.750               LF         0.021206
# FDM24                  6.135          Regular         0.079451
# FDI57                 19.850          Low Fat         0.054135
# DRC12                 17.850          Low Fat         0.037981
# NCM42                    NaN          Low Fat         0.028184
# FDA46                 13.600          Low Fat         0.196898
# FDA31                  7.100          Low Fat         0.109920
# NCJ31                 19.200          Low Fat         0.182619
# FDG52                 13.650               LF         0.065631
# NCL19                    NaN          Low Fat         0.027447
# FDS10                 19.200          Low Fat         0.035179
# FDX22                  6.785          Regular         0.038455
# NCF19                 13.000          Low Fat         0.035102
# NCE06                  5.825          Low Fat         0.091485
# DRC27                 13.800          Low Fat         0.058102
# FDE21                 12.800               LF         0.022940
# ...                      ...              ...              ...
# FDD23                  9.500          Regular         0.048645
# FDP32                  6.650          Low Fat         0.087847
# FDO31                  6.760          Regular         0.028977
# FDQ57                  7.275          Low Fat         0.000000
# FDX32                    NaN          Regular         0.099375
# FDC39                    NaN          Low Fat         0.158425
# FDU55                 16.200          Low Fat         0.035911
# FDL45                 15.600          Low Fat         0.037656
# DRK37                  5.000          Low Fat         0.044073
# FDK22                  9.800          Low Fat         0.026065
# DRG37                    NaN          Low Fat         0.000000
# FDK22                  9.800          Low Fat         0.026234
# DRH36                 16.200          Low Fat         0.033516
# DRC36                 13.000          Regular         0.045168
# DRE03                    NaN          Low Fat         0.024110
# FDF34                  9.300          Regular         0.014019
# FDZ22                  9.395          Low Fat         0.045270
# FDC44                 15.600          Low Fat         0.288892
# FDN31                    NaN          Low Fat         0.072529
# FDO03                 10.395          Regular         0.037092
# FDA01                 15.000              reg         0.054463
# NCH42                  6.860          Low Fat         0.036594
# FDF46                  7.070          Low Fat         0.094053
# DRL35                 15.700          Low Fat         0.030704
# FDW46                 13.000          Regular         0.070411
# FDB58                 10.500          Regular         0.013496
# FDD47                  7.600          Regular         0.142991
# NCO17                 10.000          Low Fat         0.073529
# FDJ26                 15.300          Regular         0.000000
# FDU37                  9.500          Regular         0.104720
#
#                              Item_Type  Item_MRP Outlet_Identifier  \
# Item_Identifier
# FDW58                      Snack Foods  107.8622            OUT049
# FDW14                            Dairy   87.3198            OUT017
# NCN55                           Others  241.7538            OUT010
# FDQ58                      Snack Foods  155.0340            OUT017
# FDY38                            Dairy  234.2300            OUT027
# FDH56            Fruits and Vegetables  117.1492            OUT046
# FDL48                     Baking Goods   50.1034            OUT018
# FDC48                     Baking Goods   81.0592            OUT027
# FDN33                      Snack Foods   95.7436            OUT045
# FDA36                     Baking Goods  186.8924            OUT017
# FDT44            Fruits and Vegetables  118.3466            OUT017
# FDQ56            Fruits and Vegetables   85.3908            OUT045
# NCC54               Health and Hygiene  240.4196            OUT019
# FDU11                           Breads  122.3098            OUT049
# DRL59                      Hard Drinks   52.0298            OUT013
# FDM24                     Baking Goods  151.6366            OUT049
# FDI57                          Seafood  198.7768            OUT045
# DRC12                      Soft Drinks  192.2188            OUT018
# NCM42                        Household  109.6912            OUT027
# FDA46                      Snack Foods  193.7136            OUT010
# FDA31            Fruits and Vegetables  175.0080            OUT013
# FDE21                                 2004       Small               Tier 2
# ...                                    ...         ...                  ...
# FDD23                                 1987        High               Tier 3
# FDP32                                 2002         NaN               Tier 2
# FDO31                                 2004       Small               Tier 2
# FDQ57                                 1987        High               Tier 3
# FDX32                                 1985      Medium               Tier 3
# FDC39                                 1985      Medium               Tier 3
# FDU55                                 1997       Small               Tier 1
# FDL45                                 1987        High               Tier 3
# DRK37                                 1999      Medium               Tier 1
# FDK22                                 1987        High               Tier 3
# DRG37                                 1985      Medium               Tier 3
# FDK22                                 2007         NaN               Tier 2
# DRH36                                 2009      Medium               Tier 3
# DRC36                                 2009      Medium               Tier 3
# DRE03                                 1985      Medium               Tier 3
# FDF34                                 1997       Small               Tier 1
# FDZ22                                 1997       Small               Tier 1
# FDC44                                 1998         NaN               Tier 3
# FDN31                                 1985      Medium               Tier 3
# FDO03                                 2007         NaN               Tier 2
# FDA01                                 1999      Medium               Tier 1
# NCH42                                 1999      Medium               Tier 1
# FDF46                                 2009      Medium               Tier 3
# DRL35                                 1997       Small               Tier 1
# FDW46                                 1999      Medium               Tier 1
# FDB58                                 1997       Small               Tier 1
# FDD47                                 2009      Medium               Tier 3
# NCO17                                 2002         NaN               Tier 2
# FDJ26                                 2007         NaN               Tier 2
# FDU37                                 2002         NaN               Tier 2
#
#                        Outlet_Type
# Item_Identifier
# FDW58            Supermarket Type1
# FDW14            Supermarket Type1
# NCN55                Grocery Store
# FDQ58            Supermarket Type1
# FDY38            Supermarket Type3
# FDH56            Supermarket Type1
# FDL48            Supermarket Type2
# FDC48            Supermarket Type3
# FDN33            Supermarket Type1
# FDA36            Supermarket Type1
# FDT44            Supermarket Type1
# FDQ56            Supermarket Type1
# NCC54                Grocery Store
# FDU11            Supermarket Type1
# DRL59            Supermarket Type1
# FDM24            Supermarket Type1
# FDI57            Supermarket Type1
# DRC12            Supermarket Type2
# NCM42            Supermarket Type3
# FDA46                Grocery Store
# FDA31            Supermarket Type1
# NCJ31            Supermarket Type1
# FDG52            Supermarket Type1
# NCL19                Grocery Store
# FDS10            Supermarket Type1
# FDX22                Grocery Store
# NCF19            Supermarket Type1
# NCE06            Supermarket Type1
# DRC27            Supermarket Type1
# FDE21            Supermarket Type1
# ...                            ...
# FDD23            Supermarket Type1
# FDP32            Supermarket Type1
# FDO31            Supermarket Type1
# FDQ57            Supermarket Type1
# FDX32            Supermarket Type3
# FDC39            Supermarket Type3
# FDU55            Supermarket Type1
# FDL45            Supermarket Type1
# DRK37            Supermarket Type1
# FDK22            Supermarket Type1
# DRG37            Supermarket Type3
# FDK22            Supermarket Type1
# DRH36            Supermarket Type2
# DRC36            Supermarket Type2
# DRE03            Supermarket Type3
# FDF34            Supermarket Type1
# FDZ22            Supermarket Type1
# FDC44                Grocery Store
# FDN31            Supermarket Type3
# FDO03            Supermarket Type1
# FDA01            Supermarket Type1
# NCH42            Supermarket Type1
# FDF46            Supermarket Type2
# DRL35            Supermarket Type1
# FDW46            Supermarket Type1
# FDB58            Supermarket Type1
# FDD47            Supermarket Type2
# NCO17            Supermarket Type1
# FDJ26            Supermarket Type1
# FDU37            Supermarket Type1
#
# [5681 rows x 10 columns]>

# %% [markdown]
# Head function gives us glimpse of data present in the Train and Test datasets. Although we can look at the data it is not so clear what are the different columns present in the dataset. By taking only one row of the dataset, lets examine the different columns.

# %%
data_Train[:1]
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# Item_Identifier
# FDA15                    9.3          Low Fat         0.016047     Dairy
#
#                  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# Item_Identifier
# FDA15            249.8092            OUT049                       1999
#
#                 Outlet_Size Outlet_Location_Type        Outlet_Type  \
# Item_Identifier
# FDA15                Medium               Tier 1  Supermarket Type1
#
#                  Item_Outlet_Sales
# Item_Identifier
# FDA15                     3735.138

# %% [markdown]
# With this it is clear that we have the columns named "Item_Identifier","Item_Weight","Item_Fat_Content","Item_Visibility","Item_Type","Item_MRP","Outlet_Identifier",
# "Outlet_Establishment_Year","Outlet_Size","Outlet_Location_Type","Outlet_Type","Item_Outlet_Sales" in our training dataset. Of all these attributes all the columns in the starting are Predictors for the outcome "Item_Outlet_Sales".
#
# Lets do the same for Test Dataset.

# %%
data_Test[:1]
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# Item_Identifier
# FDW58                  20.75          Low Fat         0.007565  Snack Foods
#
#                  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# Item_Identifier
# FDW58            107.8622            OUT049                       1999
#
#                 Outlet_Size Outlet_Location_Type        Outlet_Type
# Item_Identifier
# FDW58                Medium               Tier 1  Supermarket Type1

# %% [markdown]
# If we observe the attributes in the two datasets, we can observe that both test and train datasets have same type of columns except that in the test dataset Item_Outlet_Sales are missing, which we need to predict from the model we build from the train dataset. Now check for the datatypes of different columns in the dataset which will be helpful in further data processing operations.

# %%
data_Train.dtypes
# Out:
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
data_Test.dtypes
# Out:
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# dtype: object

# %% [markdown]
# We can see that our dataset has statistical values in them and also we have few of the categorical columns. Lets check for any of the missing data items in different attributes for our datasets.

# %%
data_Train.apply(lambda x: sum(x.isnull()))
# Out:
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# In our training dataset we have the missing data values for the columns "Item_Weight" and "Outlet_Size" each of them having missing values for 1463 and 2410 number of rows. By checking the same for Test dataset.

# %%
data_Test.apply(lambda x: sum(x.isnull()))
# Out:
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %% [markdown]
# Our Test dataset also have missing values for "Item_Weight" and "Outlet_Size" columns. We are sure that our datasets have missing values in them. We need to deal with these missing values, leaving behind missing values have implications in building a successful model. Hence, it is often adviced to take the missing values into account and impute them properly. We shall deal with the missing values in our next section "Imputing the missing values". We have seen the attributes, datatypes and number of missing values. For better understanding the values in the dataset lets have a look into the statistics of our datasets.

# %%
data_Train.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %% [markdown]
# #### Some Important Observations from the Statistics of Training dataset:

# %% [markdown]
# 1. Column "Item_Weight" has values ranging from 4.56 to 21.35 with a mean value of 12.86 (adjusted to 2 decimal points). Count is showing as 7060 although we have 8523 number of rows in our training dataset. This phenomenon is justified by missing value count of 1463.
# 2. "Item_Visibility" has values ranging from 0 to 0.33 with a mean value of 0.066. But, min value of 0 is not practically feasible in this column. Since an Item can't be sold unless it is displayed in the shelves. We will change these values in our next sections.
# 3. "Item_MRP" has values ranging from 31.29 to 266.89 with a mean value of 141.
# 4. "Outlet_Establishment_Year" has values ranging from 1985 to 2009. From this we can see that, first store started is in 1985 and the most recent store started in 2009.

# %% [markdown]
# Doing the same for our Test dataset.

# %%
data_Test.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year
# count  4705.000000      5681.000000  5681.000000                5681.000000
# mean     12.695633         0.065684   141.023273                1997.828903
# std       4.664849         0.051252    61.809091                   8.372256
# min       4.555000         0.000000    31.990000                1985.000000
# 25%       8.645000         0.027047    94.412000                1987.000000
# 50%      12.500000         0.054154   141.415400                1999.000000
# 75%      16.700000         0.093463   186.026600                2004.000000
# max      21.350000         0.323637   266.588400                2009.000000

# %% [markdown]
# In our Test dataset we have total of 5681 number of rows. Of these we have missing values for the attribute named Item_Weight. In our next steps we will deal with the missing values in the dataset.

# %% [markdown]
# ## Dealing with Missing values in the dataset

# %% [markdown]
# Having missing values in the dataset complicates the process of predicting the output and create a model that well performs. In order to deal with the missing values on the first hand we need to identify cause for missing item values in the dataset. Most of the times these data points are not recorded at the source or ignored while collecting the data. If the data points are collected and ignored while taking it into consideration it's often a good idea to re-enter those values from the source. If they were not collected at the source we need to find a way to impute those missing values.
#
#  There are many ways to deal with the missing values based on the methodology we use. One easy way is to impute those missing values with the mean values of that attribute type. Although practically it is a very simple way to deal with the missing values, the result of this method are often not so accurate. For the current project I'm going to first impute the missing values with their mean value and design a model. Later we will design model itself to specifically identify the missing values.

# %% [markdown]
# In order to avoid the duplication of process to treat the missing values separately in the Test and Train datasets, we are going to merge those two datasets and do the necessary operations.

# %%
data = pd.concat([data_Train,data_Test])

# %%
data.shape
# Out:
# (14204, 11)

# %% [markdown]
# In the combined dataset we have around 14,204 number of rows. As seen in the previous sections, we have missing values for "Item_Weight". Let's impute these item weights by mean of the Item_Weights.

# %%
data.mean()
# Out:
# Item_MRP                      141.004977
# Item_Outlet_Sales            2181.288914
# Item_Visibility                 0.065953
# Item_Weight                    12.792854
# Outlet_Establishment_Year    1997.830681
# dtype: float64

# %%
data.fillna(data.mean())
# Out:
#                 Item_Fat_Content  Item_MRP  Item_Outlet_Sales  \
# Item_Identifier
# FDA15                    Low Fat  249.8092        3735.138000
# DRC01                    Regular   48.2692         443.422800
# FDN15                    Low Fat  141.6180        2097.270000
# FDX07                    Regular  182.0950         732.380000
# NCD19                    Low Fat   53.8614         994.705200
# FDP36                    Regular   51.4008         556.608800
# FDO10                    Regular   57.6588         343.552800
# FDP10                    Low Fat  107.7622        4022.763600
# FDH17                    Regular   96.9726        1076.598600
# FDU28                    Regular  187.8214        4710.535000
# FDY07                    Low Fat   45.5402        1516.026600
# FDA03                    Regular  144.1102        2187.153000
# FDX32                    Regular  145.4786        1589.264600
# FDS46                    Regular  119.6782        2145.207600
# FDF32                    Low Fat  196.4426        1977.426000
# FDP49                    Regular   56.3614        1547.319200
# NCB42                    Low Fat  115.3492        1621.888800
# FDP49                    Regular   54.3614         718.398200
# DRI11                    Low Fat  113.2834        2303.668000
# FDU02                    Low Fat  230.5352        2748.422400
# FDN22                    Regular  250.8724        3775.086000
# FDW12                    Regular  144.5444        4064.043200
# NCB30                    Low Fat  196.5084        1587.267200
# FDC37                    Low Fat  107.6938         214.387600
# FDR28                    Regular  165.0210        4078.025000
# NCD06                    Low Fat   45.9060         838.908000
# FDV10                    Regular   42.3112        1065.280000
# DRJ59                    low fat   39.1164         308.931200
# FDE51                    Regular   45.5086         178.434400
# FDC14                    Regular   43.6454         125.836200
# ...                          ...       ...                ...
# FDD23                    Regular  186.1898        2181.288914
# FDP32                    Low Fat  126.7678        2181.288914
# FDO31                    Regular   80.2960        2181.288914
# FDQ57                    Low Fat  144.5760        2181.288914
# FDX32                    Regular  143.6786        2181.288914
# FDK22                      Snack Foods         0.026065     9.800000
# DRG37                      Soft Drinks         0.000000    12.792854
# FDK22                      Snack Foods         0.026234     9.800000
# DRH36                      Soft Drinks         0.033516    16.200000
# DRC36                      Soft Drinks         0.045168    13.000000
# DRE03                            Dairy         0.024110    12.792854
# FDF34                      Snack Foods         0.014019     9.300000
# FDZ22                      Snack Foods         0.045270     9.395000
# FDC44            Fruits and Vegetables         0.288892    15.600000
# FDN31            Fruits and Vegetables         0.072529    12.792854
# FDO03                             Meat         0.037092    10.395000
# FDA01                           Canned         0.054463    15.000000
# NCH42                        Household         0.036594     6.860000
# FDF46                      Snack Foods         0.094053     7.070000
# DRL35                      Hard Drinks         0.030704    15.700000
# FDW46                      Snack Foods         0.070411    13.000000
# FDB58                      Snack Foods         0.013496    10.500000
# FDD47                    Starchy Foods         0.142991     7.600000
# NCO17               Health and Hygiene         0.073529    10.000000
# FDJ26                           Canned         0.000000    15.300000
# FDU37                           Canned         0.104720     9.500000
#
#                  Outlet_Establishment_Year Outlet_Identifier  \
# Item_Identifier
# FDA15                                 1999            OUT049
# DRC01                                 2009            OUT018
# FDN15                                 1999            OUT049
# FDX07                                 1998            OUT010
# NCD19                                 1987            OUT013
# FDP36                                 2009            OUT018
# FDO10                                 1987            OUT013
# FDP10                                 1985            OUT027
# FDH17                                 2002            OUT045
# FDU28                                 2007            OUT017
# FDY07                                 1999            OUT049
# FDA03                                 1997            OUT046
# FDX32                                 1999            OUT049
# FDS46                                 1997            OUT046
# FDF32                                 1987            OUT013
# FDP49                                 1997            OUT046
# NCB42                                 2009            OUT018
# FDP49                                 1999            OUT049
# DRI11                                 1985            OUT027
# FDU02                                 2004            OUT035
# FDN22                                 1987            OUT013
# FDW12                                 1985            OUT027
# NCB30                                 2004            OUT035
# FDC37                                 1985            OUT019
# FDR28                                 1997            OUT046
# NCD06                                 2007            OUT017
# FDV10                                 2004            OUT035
# DRJ59                                 1987            OUT013
# FDE51                                 1998            OUT010
# FDC14                                 1985            OUT019
# ...                                    ...               ...
# FDD23                                 1987            OUT013
# FDP32                                 2002            OUT045
# FDO31                                 2004            OUT035
# FDQ57                                 1987            OUT013
# FDX32                                 1985            OUT027
# FDC39                                 1985            OUT027
# FDU55                                 1997            OUT046
# FDL45                                 1987            OUT013
# DRK37                                 1999            OUT049
# FDK22                                 1987            OUT013
# DRG37                                 1985            OUT027
# FDK22                                 2007            OUT017
# DRH36                                 2009            OUT018
# DRC36                                 2009            OUT018
# DRE03                                 1985            OUT027
# FDF34                                 1997            OUT046
# FDZ22                                 1997            OUT046
# FDC44                                 1998            OUT010
# FDN31                                 1985            OUT027
# FDO03                                 2007            OUT017
# FDA01                                 1999            OUT049
# NCH42                                 1999            OUT049
# FDF46                                 2009            OUT018
# DRL35                                 1997            OUT046
# FDW46                                 1999            OUT049
# FDB58                                 1997            OUT046
# FDD47                                 2009            OUT018
# NCO17                                 2002            OUT045
# FDJ26                                 2007            OUT017
# FDU37                                 2002            OUT045
#
#                 Outlet_Location_Type Outlet_Size        Outlet_Type
# Item_Identifier
# FDA15                         Tier 1      Medium  Supermarket Type1
# DRC01                         Tier 3      Medium  Supermarket Type2
# FDN15                         Tier 1      Medium  Supermarket Type1
# FDX07                         Tier 3         NaN      Grocery Store
# NCD19                         Tier 3        High  Supermarket Type1
# FDP36                         Tier 3      Medium  Supermarket Type2
# FDO10                         Tier 3        High  Supermarket Type1
# FDP10                         Tier 3      Medium  Supermarket Type3
# FDH17                         Tier 2         NaN  Supermarket Type1
# FDU28                         Tier 2         NaN  Supermarket Type1
# FDY07                         Tier 1      Medium  Supermarket Type1
# FDA03                         Tier 1       Small  Supermarket Type1
# FDX32                         Tier 1      Medium  Supermarket Type1
# FDS46                         Tier 1       Small  Supermarket Type1
# FDF32                         Tier 3        High  Supermarket Type1
# FDP49                         Tier 1       Small  Supermarket Type1
# NCB42                         Tier 3      Medium  Supermarket Type2
# FDP49                         Tier 1      Medium  Supermarket Type1
# DRI11                         Tier 3      Medium  Supermarket Type3
# FDU02                         Tier 2       Small  Supermarket Type1
# FDN22                         Tier 3        High  Supermarket Type1
# FDW12                         Tier 3      Medium  Supermarket Type3
# NCB30                         Tier 2       Small  Supermarket Type1
# FDC37                         Tier 1       Small      Grocery Store
# FDR28                         Tier 1       Small  Supermarket Type1
# NCD06                         Tier 2         NaN  Supermarket Type1
# FDV10                         Tier 2       Small  Supermarket Type1
# DRJ59                         Tier 3        High  Supermarket Type1
# FDE51                         Tier 3         NaN      Grocery Store
# FDC14                         Tier 1       Small      Grocery Store
# ...                              ...         ...                ...
# FDD23                         Tier 3        High  Supermarket Type1
# FDP32                         Tier 2         NaN  Supermarket Type1
# FDO31                         Tier 2       Small  Supermarket Type1
# FDQ57                         Tier 3        High  Supermarket Type1
# FDX32                         Tier 3      Medium  Supermarket Type3
# FDC39                         Tier 3      Medium  Supermarket Type3
# FDU55                         Tier 1       Small  Supermarket Type1
# FDL45                         Tier 3        High  Supermarket Type1
# DRK37                         Tier 1      Medium  Supermarket Type1
# FDK22                         Tier 3        High  Supermarket Type1
# DRG37                         Tier 3      Medium  Supermarket Type3
# FDK22                         Tier 2         NaN  Supermarket Type1
# DRH36                         Tier 3      Medium  Supermarket Type2
# DRC36                         Tier 3      Medium  Supermarket Type2
# DRE03                         Tier 3      Medium  Supermarket Type3
# FDF34                         Tier 1       Small  Supermarket Type1
# FDZ22                         Tier 1       Small  Supermarket Type1
# FDC44                         Tier 3         NaN      Grocery Store
# FDN31                         Tier 3      Medium  Supermarket Type3
# FDO03                         Tier 2         NaN  Supermarket Type1
# FDA01                         Tier 1      Medium  Supermarket Type1
# NCH42                         Tier 1      Medium  Supermarket Type1
# FDF46                         Tier 3      Medium  Supermarket Type2
# DRL35                         Tier 1       Small  Supermarket Type1
# FDW46                         Tier 1      Medium  Supermarket Type1
# FDB58                         Tier 1       Small  Supermarket Type1
# FDD47                         Tier 3      Medium  Supermarket Type2
# NCO17                         Tier 2         NaN  Supermarket Type1
# FDJ26                         Tier 2         NaN  Supermarket Type1
# FDU37                         Tier 2         NaN  Supermarket Type1
#
# [14204 rows x 11 columns]
